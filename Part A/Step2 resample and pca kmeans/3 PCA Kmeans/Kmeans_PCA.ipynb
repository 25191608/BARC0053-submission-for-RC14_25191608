# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
from matplotlib import pyplot as plt

# %% [markdown]
# ## The Data

# %%
#read the dataset
df = pd.read_csv("input/Normalized_Data.csv")
#df = pd.read_csv("Standardized_Data.csv")
df.head()
# Out:
#     id  row_index  col_index  transport_None   green15    15mins   employe  \
# 0  510         38          1       -0.555556 -0.405941 -0.980198 -0.997057
# 1  511         39          1       -0.333333 -0.306931 -0.980198 -0.996636
# 2  512         40          1       -0.333333 -0.306931 -0.980198 -0.996636
# 3  513         41          1       -0.333333 -0.306931 -0.980198 -0.996636
# 4  514         42          1       -0.333333 -0.306931 -0.980198 -0.996636
#
#    gps_join_osm_id_count  landmark_osm_id_count  \
# 0                   -1.0                   -1.0
# 1                   -1.0                   -1.0
# 2                   -1.0                   -1.0
# 3                   -1.0                   -1.0
# 4                   -1.0                   -1.0
#
#    integration_intergation_T1024 Integration R800 metric_mean  ...  \
# 0                                          -0.994957           ...
# 1                                          -0.999841           ...
# 2                                          -0.999841           ...
# 3                                          -0.999841           ...
# 4                                          -0.999841           ...
#
#    Laplus Christian  Laplus Hindu  Laplus Muslim  Laplus Acommodation_owned  \
# 0          0.058456      0.175835      -0.490617                   0.049326
# 1         -0.023711      0.158756      -0.500267                  -0.044796
# 2          0.013122      0.166412      -0.495941                  -0.002603
# 3          0.013122      0.166412      -0.495941                  -0.002603
# 4          0.013122      0.166412      -0.495941                  -0.002603
#
#    Laplus Acommodation_Private rented  Laplus Acommodation_social rented  \
# 0                           -0.095265                          -0.198957
# 1                           -0.114106                          -0.207157
# 2                           -0.105660                          -0.203481
# 3                           -0.105660                          -0.203481
# 4                           -0.105660                          -0.203481
#
#    Laplus Educational_facilities_name_count  \
# 0                                      -1.0
# 1                                      -1.0
# 2                                      -1.0
# 3                                      -1.0
# 4                                      -1.0
#
#    Laplus Healthcare_facilities_name_count  Laplus supermarket_name_count  \
# 0                                      0.5                            1.0
# 1                                      0.5                            1.0
# 2                                      0.5                            1.0
# 3                                      0.5                            1.0
# 4                                      0.5                            1.0
#
#    Laplus UGS_Green space per capita_None
# 0                               -0.040909
# 1                               -0.051158
# 2                               -0.046564
# 3                               -0.046564
# 4                               -0.046564
#
# [5 rows x 65 columns]

# %%
df.shape
# Out:
# (166993, 65)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 166993 entries, 0 to 166992
# Data columns (total 65 columns):
#  #   Column                                                             Non-Null Count   Dtype
# ---  ------                                                             --------------   -----
#  0   id                                                                 166993 non-null  int64
#  1   row_index                                                          166993 non-null  int64
#  2   col_index                                                          166993 non-null  int64
#  3   transport_None                                                     166993 non-null  float64
#  4   green15                                                            166993 non-null  float64
#  5   15mins                                                             166993 non-null  float64
#  6   employe                                                            166993 non-null  float64
#  7   gps_join_osm_id_count                                              166993 non-null  float64
#  8   landmark_osm_id_count                                              166993 non-null  float64
#  9   integration_intergation_T1024 Integration R800 metric_mean         166993 non-null  float64
#  10  choice_15m_Metric Choice R800 metric_mean                          166993 non-null  float64
#  11  BuildingHeight_(mean)                                              166993 non-null  float64
#  12  BuildingVolumn                                                     166993 non-null  float64
#  13  BuildingArea                                                       166993 non-null  float64
#  14  BuildingDensity_(area)                                             166993 non-null  float64
#  15  BuildingAge_(mean)                                                 166993 non-null  float64
#  16  VacantHouseCount                                                   166993 non-null  float64
#  17  vnl_NightLightmean                                                 166993 non-null  float64
#  18  income                                                             166993 non-null  float64
#  19  employment                                                         166993 non-null  float64
#  20  activity limited%                                                  166993 non-null  float64
#  21  work population                                                    166993 non-null  float64
#  22  BAME%_re                                                           166993 non-null  float64
#  23  no-native English speaker %                                        166993 non-null  float64
#  24  Christian                                                          166993 non-null  float64
#  25  Hindu                                                              166993 non-null  float64
#  26  Muslim                                                             166993 non-null  float64
#  27  Acommodation_owned                                                 166993 non-null  float64
#  28  Acommodation_Private rented                                        166993 non-null  float64
#  29  Acommodation_social rented                                         166993 non-null  float64
#  30  Educational_facilities_name_count                                  166993 non-null  float64
#  31  Healthcare_facilities_name_count                                   166993 non-null  float64
#  32  supermarket_name_count                                             166993 non-null  float64
#  33  UGS_Green space per capita_None                                    166993 non-null  float64
#  34  Laplus transport_None                                              166993 non-null  float64
#  35  Laplus green15                                                     166993 non-null  float64
#  36  Laplus 15mins                                                      166993 non-null  float64
#  37  Laplus employe                                                     166993 non-null  float64
#  38  Laplus gps_join_osm_id_count                                       166993 non-null  float64
#  39  Laplus landmark_osm_id_count                                       166993 non-null  float64
#  40  Laplus integration_intergation_T1024 Integration R800 metric_mean  166993 non-null  float64
#  41  Laplus choice_15m_Metric Choice R800 metric_mean                   166993 non-null  float64
#  42  Laplus BuildingHeight_(mean)                                       166993 non-null  float64
#  43  Laplus BuildingVolumn                                              166993 non-null  float64
#  44  Laplus BuildingArea                                                166993 non-null  float64
#  45  Laplus BuildingDensity_(area)                                      166993 non-null  float64
#  46  Laplus BuildingAge_(mean)                                          166993 non-null  float64
#  47  Laplus VacantHouseCount                                            166993 non-null  float64
#  48  Laplus vnl_NightLightmean                                          166993 non-null  float64
#  49  Laplus income                                                      166993 non-null  float64
#  50  Laplus employment                                                  166993 non-null  float64
#  51  Laplus activity limited%                                           166993 non-null  float64
#  52  Laplus work population                                             166993 non-null  float64
#  53  Laplus BAME%_re                                                    166993 non-null  float64
#  54  Laplus no-native English speaker %                                 166993 non-null  float64
#  55  Laplus Christian                                                   166993 non-null  float64
#  56  Laplus Hindu                                                       166993 non-null  float64
#  57  Laplus Muslim                                                      166993 non-null  float64
#  58  Laplus Acommodation_owned                                          166993 non-null  float64
#  59  Laplus Acommodation_Private rented                                 166993 non-null  float64
#  60  Laplus Acommodation_social rented                                  166993 non-null  float64
#  61  Laplus Educational_facilities_name_count                           166993 non-null  float64
#  62  Laplus Healthcare_facilities_name_count                            166993 non-null  float64
#  63  Laplus supermarket_name_count                                      166993 non-null  float64
#  64  Laplus UGS_Green space per capita_None                             166993 non-null  float64
# dtypes: float64(62), int64(3)
# memory usage: 82.8 MB

# %%
df.columns
# Out:
# Index(['id', 'row_index', 'col_index', 'transport_None', 'green15', '15mins',
#        'employe', 'gps_join_osm_id_count', 'landmark_osm_id_count',
#        'integration_intergation_T1024 Integration R800 metric_mean',
#        'choice_15m_Metric Choice R800 metric_mean', 'BuildingHeight_(mean)',
#        'BuildingVolumn', 'BuildingArea', 'BuildingDensity_(area)',
#        'BuildingAge_(mean)', 'VacantHouseCount', 'vnl_NightLightmean',
#        'income', 'employment', 'activity limited%', 'work population',
#        'BAME%_re', 'no-native English speaker %', 'Christian', 'Hindu',
#        'Muslim', 'Acommodation_owned', 'Acommodation_Private rented',
#        'Acommodation_social rented', 'Educational_facilities_name_count',
#        'Healthcare_facilities_name_count', 'supermarket_name_count',
#        'UGS_Green space per capita_None', 'Laplus transport_None',
#        'Laplus green15', 'Laplus 15mins', 'Laplus employe',
#        'Laplus gps_join_osm_id_count', 'Laplus landmark_osm_id_count',
#        'Laplus integration_intergation_T1024 Integration R800 metric_mean',
#        'Laplus choice_15m_Metric Choice R800 metric_mean',
#        'Laplus BuildingHeight_(mean)', 'Laplus BuildingVolumn',
#        'Laplus BuildingArea', 'Laplus BuildingDensity_(area)',
#        'Laplus BuildingAge_(mean)', 'Laplus VacantHouseCount',
#        'Laplus vnl_NightLightmean', 'Laplus income', 'Laplus employment',
#        'Laplus activity limited%', 'Laplus work population', 'Laplus BAME%_re',
#        'Laplus no-native English speaker %', 'Laplus Christian',
#        'Laplus Hindu', 'Laplus Muslim', 'Laplus Acommodation_owned',
#        'Laplus Acommodation_Private rented',
#        'Laplus Acommodation_social rented',
#        'Laplus Educational_facilities_name_count',
#        'Laplus Healthcare_facilities_name_count',
#        'Laplus supermarket_name_count',
#        'Laplus UGS_Green space per capita_None'],
#       dtype='object')

# %% [markdown]
# ## Clean DATA

# %%
data=df[[ 'Laplus transport_None','Laplus green15', 'Laplus 15mins', 'Laplus employe',
       'Laplus gps_join_osm_id_count', 'Laplus landmark_osm_id_count',
       'Laplus integration_intergation_T1024 Integration R800 metric_mean',
       'Laplus choice_15m_Metric Choice R800 metric_mean',
       'Laplus BuildingHeight_(mean)', 'Laplus BuildingVolumn',
       'Laplus BuildingArea', 'Laplus BuildingDensity_(area)',
       'Laplus BuildingAge_(mean)', 'Laplus VacantHouseCount',
       'Laplus vnl_NightLightmean', 'Laplus income', 'Laplus employment',
       'Laplus activity limited%', 'Laplus work population', 'Laplus BAME%_re',
       'Laplus no-native English speaker %', 'Laplus Christian',
       'Laplus Hindu', 'Laplus Muslim', 'Laplus Acommodation_owned',
       'Laplus Acommodation_Private rented',
       'Laplus Acommodation_social rented',
       'Laplus Educational_facilities_name_count',
       'Laplus Healthcare_facilities_name_count',
       'Laplus supermarket_name_count',
       'Laplus UGS_Green space per capita_None']]

'''
'transport_None', 'green15', '15mins',
       'employe', 'gps_join_osm_id_count', 'landmark_osm_id_count',
       'integration_intergation_T1024 Integration R800 metric_mean',
       'choice_15m_Metric Choice R800 metric_mean', 'BuildingHeight_(mean)',
       'BuildingVolumn', 'BuildingArea', 'BuildingDensity_(area)',
       'BuildingAge_(mean)', 'VacantHouseCount', 'vnl_NightLightmean',
       'income', 'employment', 'activity limited%', 'work population',
       'BAME%_re', 'no-native English speaker %', 'Christian', 'Hindu',
       'Muslim', 'Acommodation_owned', 'Acommodation_Private rented',
       'Acommodation_social rented', 'Educational_facilities_name_count',
       'Healthcare_facilities_name_count', 'supermarket_name_count',
       'UGS_Green space per capita_None', 
'''
# Out:
# "\n'transport_None', 'green15', '15mins',\n       'employe', 'gps_join_osm_id_count', 'landmark_osm_id_count',\n       'integration_intergation_T1024 Integration R800 metric_mean',\n       'choice_15m_Metric Choice R800 metric_mean', 'BuildingHeight_(mean)',\n       'BuildingVolumn', 'BuildingArea', 'BuildingDensity_(area)',\n       'BuildingAge_(mean)', 'VacantHouseCount', 'vnl_NightLightmean',\n       'income', 'employment', 'activity limited%', 'work population',\n       'BAME%_re', 'no-native English speaker %', 'Christian', 'Hindu',\n       'Muslim', 'Acommodation_owned', 'Acommodation_Private rented',\n       'Acommodation_social rented', 'Educational_facilities_name_count',\n       'Healthcare_facilities_name_count', 'supermarket_name_count',\n       'UGS_Green space per capita_None', \n"

# %%
data.shape
# Out:
# (166993, 31)

# %%
data.head()
# Out:
#    Laplus transport_None  Laplus green15  Laplus 15mins  Laplus employe  \
# 0               0.272727       -0.117538      -0.123077       -0.031196
# 1              -0.127273       -0.165538      -0.123077       -0.031493
# 2              -0.018182       -0.147077      -0.123077       -0.031350
# 3              -0.018182       -0.147077      -0.123077       -0.031350
# 4              -0.018182       -0.147077      -0.123077       -0.031350
#
#    Laplus gps_join_osm_id_count  Laplus landmark_osm_id_count  \
# 0                      0.534759                          0.25
# 1                      0.534759                          0.25
# 2                      0.534759                          0.25
# 3                      0.534759                          0.25
# 4                      0.534759                          0.25
#
#    Laplus integration_intergation_T1024 Integration R800 metric_mean  \
# 0                                           0.384071
# 1                                           0.384071
# 2                                           0.384071
# 3                                           0.384071
# 4                                           0.384071
#
#    Laplus choice_15m_Metric Choice R800 metric_mean  \
# 0                                          0.123321
# 1                                          0.123321
# 2                                          0.123321
# 3                                          0.123321
# 4                                          0.123321
#
#    Laplus BuildingHeight_(mean)  Laplus BuildingVolumn  ...  Laplus Christian  \
# 0                      0.078774               0.228839  ...          0.058456
# 1                      0.078774               0.228839  ...         -0.023711
# 2                      0.078774               0.228839  ...          0.013122
# 3                      0.078774               0.228839  ...          0.013122
# 4                      0.078774               0.228839  ...          0.013122
#
#    Laplus Hindu  Laplus Muslim  Laplus Acommodation_owned  \
# 0      0.175835      -0.490617                   0.049326
# 1      0.158756      -0.500267                  -0.044796
# 2      0.166412      -0.495941                  -0.002603
# 3      0.166412      -0.495941                  -0.002603
# 4      0.166412      -0.495941                  -0.002603
#
#    Laplus Acommodation_Private rented  Laplus Acommodation_social rented  \
# 0                           -0.095265                          -0.198957
# 1                           -0.114106                          -0.207157
# 2                           -0.105660                          -0.203481
# 3                           -0.105660                          -0.203481
# 4                           -0.105660                          -0.203481
#
#    Laplus Educational_facilities_name_count  \
# 0                                      -1.0
# 1                                      -1.0
# 2                                      -1.0
# 3                                      -1.0
# 4                                      -1.0
#
#    Laplus Healthcare_facilities_name_count  Laplus supermarket_name_count  \
# 0                                      0.5                            1.0
# 1                                      0.5                            1.0
# 2                                      0.5                            1.0
# 3                                      0.5                            1.0
# 4                                      0.5                            1.0
#
#    Laplus UGS_Green space per capita_None
# 0                               -0.040909
# 1                               -0.051158
# 2                               -0.046564
# 3                               -0.046564
# 4                               -0.046564
#
# [5 rows x 31 columns]

# %%
data.isnull().values.any()
# Out:
# np.False_

# %%
datalocation=df[['id']]

# %%
datalocation.head()
# Out:
#     id
# 0  510
# 1  511
# 2  512
# 3  513
# 4  514

# %% [markdown]
# ## Visualisation

# %%
data.corr()
# Out:
#                                                     Laplus transport_None  \
# Laplus transport_None                                            1.000000
# Laplus green15                                                   0.130126
# Laplus 15mins                                                    0.103685
# Laplus employe                                                   0.051824
# Laplus gps_join_osm_id_count                                    -0.004541
# Laplus landmark_osm_id_count                                    -0.002912
# Laplus integration_intergation_T1024 Integratio...              -0.000466
# Laplus choice_15m_Metric Choice R800 metric_mean                -0.000901
# Laplus BuildingHeight_(mean)                                     0.000663
# Laplus BuildingVolumn                                            0.004746
# Laplus BuildingArea                                              0.005852
# Laplus BuildingDensity_(area)                                    0.005852
# Laplus BuildingAge_(mean)                                        0.118487
# Laplus VacantHouseCount                                          0.066400
# Laplus vnl_NightLightmean                                        0.001649
# Laplus income                                                    0.129227
# Laplus employment                                                0.221444
# Laplus activity limited%                                         0.179138
# Laplus work population                                           0.273158
# Laplus BAME%_re                                                  0.151925
# Laplus no-native English speaker %                               0.169971
# Laplus Christian                                                 0.202845
# Laplus Hindu                                                     0.111388
# Laplus Muslim                                                    0.081793
# Laplus Acommodation_owned                                        0.119568
# Laplus Acommodation_Private rented                               0.140727
# Laplus Acommodation_social rented                                0.061487
# Laplus Educational_facilities_name_count                         0.002930
# Laplus Healthcare_facilities_name_count                         -0.003540
# Laplus supermarket_name_count                                   -0.003013
# Laplus UGS_Green space per capita_None                           0.001310
#
#                                                     Laplus green15  \
# Laplus transport_None                                     0.130126
# Laplus green15                                            1.000000
# Laplus 15mins                                             0.127448
# Laplus employe                                           -0.047752
# Laplus gps_join_osm_id_count                             -0.002243
# Laplus landmark_osm_id_count                             -0.001847
# Laplus integration_intergation_T1024 Integratio...        0.001044
# Laplus choice_15m_Metric Choice R800 metric_mean         -0.004440
# Laplus BuildingHeight_(mean)                             -0.000573
# Laplus BuildingVolumn                                    -0.003033
# Laplus BuildingArea                                      -0.002444
# Laplus BuildingDensity_(area)                            -0.002444
# Laplus BuildingAge_(mean)                                 0.143991
# Laplus VacantHouseCount                                  -0.006290
# Laplus vnl_NightLightmean                                 0.000452
# Laplus income                                             0.335902
# Laplus employment                                         0.484435
# Laplus activity limited%                                  0.409229
# Laplus work population                                    0.544713
# Laplus BAME%_re                                           0.264043
# Laplus no-native English speaker %                        0.176506
# Laplus Christian                                          0.524729
# Laplus Hindu                                              0.032437
# Laplus Muslim                                             0.139588
# Laplus Acommodation_owned                                 0.321820
# Laplus Acommodation_Private rented                        0.094958
# Laplus Acommodation_social rented                         0.128618
# Laplus Educational_facilities_name_count                  0.001422
# Laplus Healthcare_facilities_name_count                   0.001184
# Laplus supermarket_name_count                            -0.005568
# Laplus UGS_Green space per capita_None                    0.048873
#
#                                                     Laplus 15mins  \
# Laplus transport_None                                    0.103685
# Laplus green15                                           0.127448
# Laplus 15mins                                            1.000000
# Laplus employe                                           0.012167
# Laplus gps_join_osm_id_count                             0.002830
# Laplus landmark_osm_id_count                            -0.000102
# Laplus integration_intergation_T1024 Integratio...       0.000098
# Laplus choice_15m_Metric Choice R800 metric_mean         0.003460
# Laplus BuildingHeight_(mean)                             0.005359
# Laplus BuildingVolumn                                    0.002238
# Laplus BuildingArea                                      0.000562
# Laplus BuildingDensity_(area)                            0.000562
# Laplus BuildingAge_(mean)                                0.035938
# Laplus VacantHouseCount                                  0.033118
# Laplus vnl_NightLightmean                                0.000698
# Laplus income                                            0.111030
# Laplus employment                                        0.181350
# Laplus activity limited%                                 0.122739
# Laplus work population                                   0.208410
# Laplus BAME%_re                                          0.113923
# Laplus no-native English speaker %                       0.080816
# Laplus Christian                                         0.184074
# Laplus Hindu                                             0.025663
# Laplus Muslim                                            0.034477
# Laplus Acommodation_owned                                0.118899
# Laplus Acommodation_Private rented                       0.102642
# Laplus Acommodation_social rented                        0.083150
# Laplus Educational_facilities_name_count                 0.006269
# Laplus Healthcare_facilities_name_count                  0.002591
# Laplus supermarket_name_count                            0.001898
# Laplus UGS_Green space per capita_None                   0.031885
#
#                                                     Laplus employe  \
# Laplus transport_None                                     0.051824
# Laplus green15                                           -0.047752
# Laplus 15mins                                             0.012167
# Laplus employe                                            1.000000
# Laplus gps_join_osm_id_count                              0.005348
# Laplus landmark_osm_id_count                              0.002083
# Laplus integration_intergation_T1024 Integratio...        0.001452
# Laplus choice_15m_Metric Choice R800 metric_mean          0.004211
# Laplus BuildingHeight_(mean)                              0.010093
# Laplus BuildingVolumn                                     0.012321
# Laplus BuildingArea                                       0.001290
# Laplus BuildingDensity_(area)                             0.001290
# Laplus BuildingAge_(mean)                                -0.005085
# Laplus VacantHouseCount                                   0.027556
# Laplus vnl_NightLightmean                                -0.009128
# Laplus income                                             0.021299
# Laplus employment                                         0.052707
# Laplus activity limited%                                 -0.010331
# Laplus work population                                    0.023711
# Laplus BAME%_re                                          -0.020527
# Laplus no-native English speaker %                        0.029194
# Laplus Christian                                          0.025772
# Laplus Hindu                                              0.007582
# Laplus Muslim                                            -0.008077
# Laplus Acommodation_owned                                 0.015822
# Laplus Acommodation_Private rented                        0.062942
# Laplus Acommodation_social rented                        -0.035705
# Laplus Educational_facilities_name_count                  0.005001
# Laplus Healthcare_facilities_name_count                   0.005456
# Laplus supermarket_name_count                             0.000804
# Laplus UGS_Green space per capita_None                   -0.003790
#
#                                                     Laplus gps_join_osm_id_count  \
# Laplus transport_None                                                  -0.004541
# Laplus green15                                                         -0.002243
# Laplus 15mins                                                           0.002830
# Laplus employe                                                          0.005348
# Laplus gps_join_osm_id_count                                            1.000000
# Laplus landmark_osm_id_count                                            0.044541
# Laplus integration_intergation_T1024 Integratio...                      0.015092
# Laplus choice_15m_Metric Choice R800 metric_mean                        0.021081
# Laplus BuildingHeight_(mean)                                           -0.007243
# Laplus BuildingVolumn                                                  -0.128634
# Laplus BuildingArea                                                    -0.109618
# Laplus BuildingDensity_(area)                                          -0.109618
# Laplus BuildingAge_(mean)                                              -0.002786
# Laplus VacantHouseCount                                                -0.006671
# Laplus vnl_NightLightmean                                               0.003312
# Laplus income                                                          -0.002632
# Laplus employment                                                       0.001273
# Laplus activity limited%                                               -0.003006
# Laplus work population                                                  0.002053
# Laplus BAME%_re                                                        -0.000623
# Laplus no-native English speaker %                                      0.003146
# Laplus Christian                                                       -0.000183
# Laplus Hindu                                                            0.000337
# Laplus Muslim                                                          -0.001866
# Laplus Acommodation_owned                                              -0.003799
# Laplus Acommodation_Private rented                                      0.000926
# Laplus Acommodation_social rented                                      -0.006552
# Laplus Educational_facilities_name_count                                0.007281
# Laplus Healthcare_facilities_name_count                                 0.020596
# Laplus supermarket_name_count                                           0.014454
# Laplus UGS_Green space per capita_None                                  0.006477
#
#                                                     Laplus landmark_osm_id_count  \
# Laplus transport_None                                                  -0.002912
# Laplus green15                                                         -0.001847
# Laplus 15mins                                                          -0.000102
# Laplus employe                                                          0.002083
# Laplus gps_join_osm_id_count                                            0.044541
# Laplus landmark_osm_id_count                                            1.000000
# Laplus integration_intergation_T1024 Integratio...                      0.003589
# Laplus choice_15m_Metric Choice R800 metric_mean                        0.008920
# Laplus BuildingHeight_(mean)                                            0.004773
# Laplus BuildingVolumn                                                  -0.009345
# Laplus BuildingArea                                                    -0.011036
# Laplus BuildingDensity_(area)                                          -0.011036
# Laplus BuildingAge_(mean)                                               0.005572
# Laplus VacantHouseCount                                                 0.000215
# Laplus vnl_NightLightmean                                               0.001769
# Laplus income                                                           0.003077
# Laplus employment                                                       0.000793
# Laplus activity limited%                                               -0.002807
# Laplus work population                                                 -0.001103
# Laplus BAME%_re                                                        -0.004235
# Laplus no-native English speaker %                                     -0.003814
# Laplus Christian                                                        0.000478
# Laplus Hindu                                                           -0.002339
# Laplus Muslim                                                          -0.002446
# Laplus Acommodation_owned                                               0.003025
# Laplus Acommodation_Private rented                                     -0.001125
# Laplus Acommodation_social rented                                       0.000766
# Laplus Educational_facilities_name_count                               -0.011918
# Laplus Healthcare_facilities_name_count                                -0.003970
# Laplus supermarket_name_count                                           0.005980
# Laplus UGS_Green space per capita_None                                 -0.004753
#
#                                                     Laplus integration_intergation_T1024 Integration R800 metric_mean  \
# Laplus transport_None                                                                       -0.000466
# Laplus green15                                                                               0.001044
# Laplus 15mins                                                                                0.000098
# Laplus employe                                                                               0.001452
# Laplus gps_join_osm_id_count                                                                 0.015092
# Laplus landmark_osm_id_count                                                                 0.003589
# Laplus integration_intergation_T1024 Integratio...                                           1.000000
# Laplus choice_15m_Metric Choice R800 metric_mean                                             0.238009
# Laplus BuildingHeight_(mean)                                                                 0.000917
# Laplus BuildingVolumn                                                                        0.002524
# Laplus BuildingArea                                                                          0.005556
# Laplus BuildingDensity_(area)                                                                0.005556
# Laplus BuildingAge_(mean)                                                                    0.003600
# Laplus VacantHouseCount                                                                     -0.001488
# Laplus vnl_NightLightmean                                                                    0.001313
# Laplus income                                                                                0.001752
# Laplus employment                                                                            0.002414
# Laplus activity limited%                                                                     0.000018
# Laplus work population                                                                       0.000920
# Laplus BAME%_re                                                                              0.000129
# Laplus no-native English speaker %                                                          -0.000311
# Laplus Christian                                                                             0.002679
# Laplus Hindu                                                                                 0.000390
# Laplus Muslim                                                                               -0.003166
# Laplus Acommodation_owned                                                                   -0.003350
# Laplus Acommodation_Private rented                                                          -0.004287
# Laplus Acommodation_social rented                                                           -0.000781
# Laplus Educational_facilities_name_count                                                    -0.002797
# Laplus Healthcare_facilities_name_count                                                      0.008123
# Laplus supermarket_name_count                                                                0.007490
# Laplus UGS_Green space per capita_None                                                       0.000026
#
#                                                     Laplus choice_15m_Metric Choice R800 metric_mean  \
# Laplus transport_None                                                                      -0.000901
# Laplus green15                                                                             -0.004440
# Laplus 15mins                                                                               0.003460
# Laplus employe                                                                              0.004211
# Laplus gps_join_osm_id_count                                                                0.021081
# Laplus landmark_osm_id_count                                                                0.008920
# Laplus integration_intergation_T1024 Integratio...                                          0.238009
# Laplus choice_15m_Metric Choice R800 metric_mean                                            1.000000
# Laplus BuildingHeight_(mean)                                                                0.000179
# Laplus BuildingVolumn                                                                       0.004201
# Laplus BuildingArea                                                                         0.011578
# Laplus BuildingDensity_(area)                                                               0.011578
# Laplus BuildingAge_(mean)                                                                   0.005291
# Laplus VacantHouseCount                                                                     0.001578
# Laplus vnl_NightLightmean                                                                   0.006923
# Laplus income                                                                               0.000823
# Laplus employment                                                                           0.001253
# Laplus activity limited%                                                                   -0.002375
# Laplus work population                                                                      0.001133
# Laplus BAME%_re                                                                            -0.000188
# Laplus no-native English speaker %                                                         -0.000832
# Laplus Christian                                                                           -0.001417
# Laplus Hindu                                                                                0.004929
# Laplus Muslim                                                                              -0.004260
# Laplus Acommodation_owned                                                                  -0.001426
# Laplus Acommodation_Private rented                                                          0.001657
# Laplus Acommodation_social rented                                                           0.000332
# Laplus Educational_facilities_name_count                                                   -0.006812
# Laplus Healthcare_facilities_name_count                                                     0.011342
# Laplus supermarket_name_count                                                               0.017514
# Laplus UGS_Green space per capita_None                                                     -0.000604
#
#                                                     Laplus BuildingHeight_(mean)  \
# Laplus transport_None                                                   0.000663
# Laplus green15                                                         -0.000573
# Laplus 15mins                                                           0.005359
# Laplus employe                                                          0.010093
# Laplus gps_join_osm_id_count                                           -0.007243
# Laplus landmark_osm_id_count                                            0.004773
# Laplus integration_intergation_T1024 Integratio...                      0.000917
# Laplus choice_15m_Metric Choice R800 metric_mean                        0.000179
# Laplus BuildingHeight_(mean)                                            1.000000
# Laplus BuildingVolumn                                                   0.365926
# Laplus BuildingArea                                                     0.132532
# Laplus BuildingDensity_(area)                                           0.132532
# Laplus BuildingAge_(mean)                                              -0.015468
# Laplus VacantHouseCount                                                 0.017898
# Laplus vnl_NightLightmean                                               0.008668
# Laplus income                                                          -0.011333
# Laplus employment                                                      -0.008453
# Laplus activity limited%                                                0.002729
# Laplus work population                                                 -0.002102
# Laplus BAME%_re                                                         0.017436
# Laplus no-native English speaker %                                      0.017601
# Laplus Christian                                                        0.000341
# Laplus Hindu                                                           -0.003592
# Laplus Muslim                                                           0.013275
# Laplus Acommodation_owned                                              -0.011372
# Laplus Acommodation_Private rented                                     -0.005723
# Laplus Acommodation_social rented                                       0.014451
# Laplus Educational_facilities_name_count                                0.007832
# Laplus Healthcare_facilities_name_count                                -0.005748
# Laplus supermarket_name_count                                          -0.005727
# Laplus UGS_Green space per capita_None                                  0.012528
#
#                                                     Laplus BuildingVolumn  \
# Laplus transport_None                                            0.004746
# Laplus green15                                                  -0.003033
# Laplus 15mins                                                    0.002238
# Laplus employe                                                   0.012321
# Laplus gps_join_osm_id_count                                    -0.128634
# Laplus landmark_osm_id_count                                    -0.009345
# Laplus integration_intergation_T1024 Integratio...               0.002524
# Laplus choice_15m_Metric Choice R800 metric_mean                 0.004201
# Laplus BuildingHeight_(mean)                                     0.365926
# Laplus BuildingVolumn                                            1.000000
# Laplus BuildingArea                                              0.733730
# Laplus BuildingDensity_(area)                                    0.733730
# Laplus BuildingAge_(mean)                                       -0.007730
# Laplus VacantHouseCount                                          0.004044
# Laplus vnl_NightLightmean                                        0.002283
# Laplus income                                                    0.001898
# Laplus employment                                                0.000559
# Laplus activity limited%                                        -0.003417
# Laplus work population                                           0.004895
# Laplus BAME%_re                                                  0.003101
# Laplus no-native English speaker %                               0.007312
# Laplus Christian                                                 0.001262
# Laplus Hindu                                                     0.002232
# Laplus Muslim                                                    0.000844
# Laplus Acommodation_owned                                        0.000988
# Laplus Acommodation_Private rented                               0.007411
# Laplus Acommodation_social rented                                0.005792
# Laplus Educational_facilities_name_count                        -0.020803
# Laplus Healthcare_facilities_name_count                         -0.001964
# Laplus supermarket_name_count                                    0.025699
# Laplus UGS_Green space per capita_None                           0.008231
#
#                                                     ...  Laplus Christian  \
# Laplus transport_None                               ...          0.202845
# Laplus green15                                      ...          0.524729
# Laplus 15mins                                       ...          0.184074
# Laplus employe                                      ...          0.025772
# Laplus gps_join_osm_id_count                        ...         -0.000183
# Laplus landmark_osm_id_count                        ...          0.000478
# Laplus integration_intergation_T1024 Integratio...  ...          0.002679
# Laplus choice_15m_Metric Choice R800 metric_mean    ...         -0.001417
# Laplus BuildingHeight_(mean)                        ...          0.000341
# Laplus BuildingVolumn                               ...          0.001262
# Laplus BuildingArea                                 ...          0.001953
# Laplus BuildingDensity_(area)                       ...          0.001953
# Laplus BuildingAge_(mean)                           ...          0.306046
# Laplus VacantHouseCount                             ...         -0.009596
# Laplus vnl_NightLightmean                           ...         -0.001166
# Laplus income                                       ...          0.593454
# Laplus employment                                   ...          0.799339
# Laplus activity limited%                            ...          0.653601
# Laplus work population                              ...          0.807726
# Laplus BAME%_re                                     ...          0.214724
# Laplus no-native English speaker %                  ...          0.104048
# Laplus Christian                                    ...          1.000000
# Laplus Hindu                                        ...         -0.030364
# Laplus Muslim                                       ...         -0.028925
# Laplus Acommodation_owned                           ...          0.585305
# Laplus Acommodation_Private rented                  ...          0.097328
# Laplus Acommodation_social rented                   ...          0.155002
# Laplus Educational_facilities_name_count            ...          0.003240
# Laplus Healthcare_facilities_name_count             ...         -0.000104
# Laplus supermarket_name_count                       ...         -0.003172
# Laplus UGS_Green space per capita_None              ...          0.060356
#
#                                                     Laplus Hindu  \
# Laplus transport_None                                   0.111388
# Laplus green15                                          0.032437
# Laplus 15mins                                           0.025663
# Laplus employe                                          0.007582
# Laplus gps_join_osm_id_count                            0.000337
# Laplus landmark_osm_id_count                           -0.002339
# Laplus integration_intergation_T1024 Integratio...      0.000390
# Laplus choice_15m_Metric Choice R800 metric_mean        0.004929
# Laplus BuildingHeight_(mean)                           -0.003592
# Laplus BuildingVolumn                                   0.002232
# Laplus BuildingArea                                     0.001643
# Laplus BuildingDensity_(area)                           0.001643
# Laplus BuildingAge_(mean)                               0.094290
# Laplus VacantHouseCount                                 0.016540
# Laplus vnl_NightLightmean                               0.000278
# Laplus income                                           0.195244
# Laplus employment                                       0.158909
# Laplus activity limited%                               -0.031345
# Laplus work population                                  0.187310
# Laplus BAME%_re                                         0.290938
# Laplus no-native English speaker %                      0.289036
# Laplus Christian                                       -0.030364
# Laplus Hindu                                            1.000000
# Laplus Muslim                                           0.040546
# Laplus Acommodation_owned                               0.093726
# Laplus Acommodation_Private rented                      0.107164
# Laplus Acommodation_social rented                      -0.164096
# Laplus Educational_facilities_name_count                0.008035
# Laplus Healthcare_facilities_name_count                 0.003023
# Laplus supermarket_name_count                          -0.000310
# Laplus UGS_Green space per capita_None                 -0.010290
#
#                                                     Laplus Muslim  \
# Laplus transport_None                                    0.081793
# Laplus green15                                           0.139588
# Laplus 15mins                                            0.034477
# Laplus employe                                          -0.008077
# Laplus gps_join_osm_id_count                            -0.001866
# Laplus landmark_osm_id_count                            -0.002446
# Laplus integration_intergation_T1024 Integratio...      -0.003166
# Laplus choice_15m_Metric Choice R800 metric_mean        -0.004260
# Laplus BuildingHeight_(mean)                             0.013275
# Laplus BuildingVolumn                                    0.000844
# Laplus BuildingArea                                      0.000191
# Laplus BuildingDensity_(area)                            0.000191
# Laplus BuildingAge_(mean)                               -0.032125
# Laplus VacantHouseCount                                  0.043502
# Laplus vnl_NightLightmean                                0.002050
# Laplus income                                           -0.241390
# Laplus employment                                       -0.115004
# Laplus activity limited%                                 0.321502
# Laplus work population                                   0.054029
# Laplus BAME%_re                                          0.717175
# Laplus no-native English speaker %                       0.537023
# Laplus Christian                                        -0.028925
# Laplus Hindu                                             0.040546
# Laplus Muslim                                            1.000000
# Laplus Acommodation_owned                               -0.095681
# Laplus Acommodation_Private rented                      -0.100695
# Laplus Acommodation_social rented                        0.240641
# Laplus Educational_facilities_name_count                 0.000338
# Laplus Healthcare_facilities_name_count                  0.002410
# Laplus supermarket_name_count                           -0.001139
# Laplus UGS_Green space per capita_None                   0.030261
#
#                                                     Laplus Acommodation_owned  \
# Laplus transport_None                                                0.119568
# Laplus green15                                                       0.321820
# Laplus 15mins                                                        0.118899
# Laplus employe                                                       0.015822
# Laplus gps_join_osm_id_count                                        -0.003799
# Laplus landmark_osm_id_count                                         0.003025
# Laplus integration_intergation_T1024 Integratio...                  -0.003350
# Laplus choice_15m_Metric Choice R800 metric_mean                    -0.001426
# Laplus BuildingHeight_(mean)                                        -0.011372
# Laplus BuildingVolumn                                                0.000988
# Laplus BuildingArea                                                  0.007391
# Laplus BuildingDensity_(area)                                        0.007391
# Laplus BuildingAge_(mean)                                            0.427512
# Laplus VacantHouseCount                                              0.103079
# Laplus vnl_NightLightmean                                            0.000029
# Laplus income                                                        0.664154
# Laplus employment                                                    0.680475
# Laplus activity limited%                                             0.288023
# Laplus work population                                               0.586880
# Laplus BAME%_re                                                     -0.063168
# Laplus no-native English speaker %                                  -0.096368
# Laplus Christian                                                     0.585305
# Laplus Hindu                                                         0.093726
# Laplus Muslim                                                       -0.095681
# Laplus Acommodation_owned                                            1.000000
# Laplus Acommodation_Private rented                                   0.463687
# Laplus Acommodation_social rented                                    0.025268
# Laplus Educational_facilities_name_count                             0.004266
# Laplus Healthcare_facilities_name_count                             -0.003125
# Laplus supermarket_name_count                                       -0.003806
# Laplus UGS_Green space per capita_None                               0.041776
#
#                                                     Laplus Acommodation_Private rented  \
# Laplus transport_None                                                         0.140727
# Laplus green15                                                                0.094958
# Laplus 15mins                                                                 0.102642
# Laplus employe                                                                0.062942
# Laplus gps_join_osm_id_count                                                  0.000926
# Laplus landmark_osm_id_count                                                 -0.001125
# Laplus integration_intergation_T1024 Integratio...                           -0.004287
# Laplus choice_15m_Metric Choice R800 metric_mean                              0.001657
# Laplus BuildingHeight_(mean)                                                 -0.005723
# Laplus BuildingVolumn                                                         0.007411
# Laplus BuildingArea                                                           0.012325
# Laplus BuildingDensity_(area)                                                 0.012325
# Laplus BuildingAge_(mean)                                                     0.103163
# Laplus VacantHouseCount                                                       0.331917
# Laplus vnl_NightLightmean                                                    -0.000877
# Laplus income                                                                 0.187724
# Laplus employment                                                             0.285860
# Laplus activity limited%                                                     -0.080754
# Laplus work population                                                        0.282203
# Laplus BAME%_re                                                              -0.021693
# Laplus no-native English speaker %                                            0.224857
# Laplus Christian                                                              0.097328
# Laplus Hindu                                                                  0.107164
# Laplus Muslim                                                                -0.100695
# Laplus Acommodation_owned                                                     0.463687
# Laplus Acommodation_Private rented                                            1.000000
# Laplus Acommodation_social rented                                             0.201243
# Laplus Educational_facilities_name_count                                      0.004626
# Laplus Healthcare_facilities_name_count                                      -0.004783
# Laplus supermarket_name_count                                                 0.006623
# Laplus UGS_Green space per capita_None                                        0.010792
#
#                                                     Laplus Acommodation_social rented  \
# Laplus transport_None                                                        0.061487
# Laplus green15                                                               0.128618
# Laplus 15mins                                                                0.083150
# Laplus employe                                                              -0.035705
# Laplus gps_join_osm_id_count                                                -0.006552
# Laplus landmark_osm_id_count                                                 0.000766
# Laplus integration_intergation_T1024 Integratio...                          -0.000781
# Laplus choice_15m_Metric Choice R800 metric_mean                             0.000332
# Laplus BuildingHeight_(mean)                                                 0.014451
# Laplus BuildingVolumn                                                        0.005792
# Laplus BuildingArea                                                          0.001719
# Laplus BuildingDensity_(area)                                                0.001719
# Laplus BuildingAge_(mean)                                                   -0.192300
# Laplus VacantHouseCount                                                      0.190394
# Laplus vnl_NightLightmean                                                    0.004117
# Laplus income                                                               -0.301999
# Laplus employment                                                           -0.107859
# Laplus activity limited%                                                     0.411302
# Laplus work population                                                       0.008498
# Laplus BAME%_re                                                              0.313028
# Laplus no-native English speaker %                                           0.164068
# Laplus Christian                                                             0.155002
# Laplus Hindu                                                                -0.164096
# Laplus Muslim                                                                0.240641
# Laplus Acommodation_owned                                                    0.025268
# Laplus Acommodation_Private rented                                           0.201243
# Laplus Acommodation_social rented                                            1.000000
# Laplus Educational_facilities_name_count                                     0.002311
# Laplus Healthcare_facilities_name_count                                      0.001660
# Laplus supermarket_name_count                                               -0.000967
# Laplus UGS_Green space per capita_None                                       0.054305
#
#                                                     Laplus Educational_facilities_name_count  \
# Laplus transport_None                                                               0.002930
# Laplus green15                                                                      0.001422
# Laplus 15mins                                                                       0.006269
# Laplus employe                                                                      0.005001
# Laplus gps_join_osm_id_count                                                        0.007281
# Laplus landmark_osm_id_count                                                       -0.011918
# Laplus integration_intergation_T1024 Integratio...                                 -0.002797
# Laplus choice_15m_Metric Choice R800 metric_mean                                   -0.006812
# Laplus BuildingHeight_(mean)                                                        0.007832
# Laplus BuildingVolumn                                                              -0.020803
# Laplus BuildingArea                                                                -0.053229
# Laplus BuildingDensity_(area)                                                      -0.053229
# Laplus BuildingAge_(mean)                                                           0.002136
# Laplus VacantHouseCount                                                             0.002938
# Laplus vnl_NightLightmean                                                           0.005425
# Laplus income                                                                       0.001778
# Laplus employment                                                                   0.002812
# Laplus activity limited%                                                            0.003640
# Laplus work population                                                              0.002121
# Laplus BAME%_re                                                                     0.003347
# Laplus no-native English speaker %                                                  0.005823
# Laplus Christian                                                                    0.003240
# Laplus Hindu                                                                        0.008035
# Laplus Muslim                                                                       0.000338
# Laplus Acommodation_owned                                                           0.004266
# Laplus Acommodation_Private rented                                                  0.004626
# Laplus Acommodation_social rented                                                   0.002311
# Laplus Educational_facilities_name_count                                            1.000000
# Laplus Healthcare_facilities_name_count                                             0.003242
# Laplus supermarket_name_count                                                      -0.000599
# Laplus UGS_Green space per capita_None                                              0.002651
#
#                                                     Laplus Healthcare_facilities_name_count  \
# Laplus transport_None                                                             -0.003540
# Laplus green15                                                                     0.001184
# Laplus 15mins                                                                      0.002591
# Laplus employe                                                                     0.005456
# Laplus gps_join_osm_id_count                                                       0.020596
# Laplus landmark_osm_id_count                                                      -0.003970
# Laplus integration_intergation_T1024 Integratio...                                 0.008123
# Laplus choice_15m_Metric Choice R800 metric_mean                                   0.011342
# Laplus BuildingHeight_(mean)                                                      -0.005748
# Laplus BuildingVolumn                                                             -0.001964
# Laplus BuildingArea                                                                0.012861
# Laplus BuildingDensity_(area)                                                      0.012861
# Laplus BuildingAge_(mean)                                                         -0.000017
# Laplus VacantHouseCount                                                            0.004892
# Laplus vnl_NightLightmean                                                          0.005532
# Laplus income                                                                     -0.003075
# Laplus employment                                                                 -0.000702
# Laplus activity limited%                                                           0.002999
# Laplus work population                                                            -0.002303
# Laplus BAME%_re                                                                    0.003773
# Laplus no-native English speaker %                                                 0.001541
# Laplus Christian                                                                  -0.000104
# Laplus Hindu                                                                       0.003023
# Laplus Muslim                                                                      0.002410
# Laplus Acommodation_owned                                                         -0.003125
# Laplus Acommodation_Private rented                                                -0.004783
# Laplus Acommodation_social rented                                                  0.001660
# Laplus Educational_facilities_name_count                                           0.003242
# Laplus Healthcare_facilities_name_count                                            1.000000
# Laplus supermarket_name_count                                                      0.032891
# Laplus UGS_Green space per capita_None                                            -0.001406
#
#                                                     Laplus supermarket_name_count  \
# Laplus transport_None                                                   -0.003013
# Laplus green15                                                          -0.005568
# Laplus 15mins                                                            0.001898
# Laplus employe                                                           0.000804
# Laplus gps_join_osm_id_count                                             0.014454
# Laplus landmark_osm_id_count                                             0.005980
# Laplus integration_intergation_T1024 Integratio...                       0.007490
# Laplus choice_15m_Metric Choice R800 metric_mean                         0.017514
# Laplus BuildingHeight_(mean)                                            -0.005727
# Laplus BuildingVolumn                                                    0.025699
# Laplus BuildingArea                                                      0.060519
# Laplus BuildingDensity_(area)                                            0.060519
# Laplus BuildingAge_(mean)                                               -0.004237
# Laplus VacantHouseCount                                                 -0.001915
# Laplus vnl_NightLightmean                                                0.005059
# Laplus income                                                           -0.002653
# Laplus employment                                                       -0.000660
# Laplus activity limited%                                                -0.004385
# Laplus work population                                                  -0.000176
# Laplus BAME%_re                                                         -0.001219
# Laplus no-native English speaker %                                       0.003753
# Laplus Christian                                                        -0.003172
# Laplus Hindu                                                            -0.000310
# Laplus Muslim                                                           -0.001139
# Laplus Acommodation_owned                                               -0.003806
# Laplus Acommodation_Private rented                                       0.006623
# Laplus Acommodation_social rented                                       -0.000967
# Laplus Educational_facilities_name_count                                -0.000599
# Laplus Healthcare_facilities_name_count                                  0.032891
# Laplus supermarket_name_count                                            1.000000
# Laplus UGS_Green space per capita_None                                  -0.005960
#
#                                                     Laplus UGS_Green space per capita_None
# Laplus transport_None                                                             0.001310
# Laplus green15                                                                    0.048873
# Laplus 15mins                                                                     0.031885
# Laplus employe                                                                   -0.003790
# Laplus gps_join_osm_id_count                                                      0.006477
# Laplus landmark_osm_id_count                                                     -0.004753
# Laplus integration_intergation_T1024 Integratio...                                0.000026
# Laplus choice_15m_Metric Choice R800 metric_mean                                 -0.000604
# Laplus BuildingHeight_(mean)                                                      0.012528
# Laplus BuildingVolumn                                                             0.008231
# Laplus BuildingArea                                                               0.015007
# Laplus BuildingDensity_(area)                                                     0.015007
# Laplus BuildingAge_(mean)                                                         0.014083
# Laplus VacantHouseCount                                                           0.003613
# Laplus vnl_NightLightmean                                                         0.001186
# Laplus income                                                                     0.021420
# Laplus employment                                                                 0.060297
# Laplus activity limited%                                                          0.060496
# Laplus work population                                                            0.071225
# Laplus BAME%_re                                                                   0.037100
# Laplus no-native English speaker %                                                0.015170
# Laplus Christian                                                                  0.060356
# Laplus Hindu                                                                     -0.010290
# Laplus Muslim                                                                     0.030261
# Laplus Acommodation_owned                                                         0.041776
# Laplus Acommodation_Private rented                                                0.010792
# Laplus Acommodation_social rented                                                 0.054305
# Laplus Educational_facilities_name_count                                          0.002651
# Laplus Healthcare_facilities_name_count                                          -0.001406
# Laplus supermarket_name_count                                                    -0.005960
# Laplus UGS_Green space per capita_None                                            1.000000
#
# [31 rows x 31 columns]

# %%
'''
plt.figure(figsize=(12,8))
heatmap = sns.heatmap(data.corr(), cmap = 'viridis')
plt.title('Heatmap of data correlation')
'''

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from matplotlib.colors import LinearSegmentedColormap

# Use the dark_background context manager to maintain a black background with white text style
with plt.style.context('dark_background'):
    plt.figure(figsize=(36,24))

    corr = data.corr()

    # 1. Find the maximum boundary of absolute values
    limit = np.max(np.abs(corr.values))

    # Define a custom color list: negative values (cyan) -> 0 (black) -> positive values (purple)
    colors = ['cyan', 'black', 'purple']
    # Create a custom colormap
    cmap_custom = LinearSegmentedColormap.from_list('cyan_black_purple', colors)

    # 2. Plotting
    sns.heatmap(corr,
                vmin=-limit,
                vmax=limit,
                center=0,
                cmap=cmap_custom,
                annot=False,      # Modification: Do not display text
                square=True,      # Modification: Force each cell to be a square
                linewidths=0.5,   # Grid line width, can be adjusted as needed
                linecolor='black' # Grid line color
               )

    plt.title('Heatmap of data correlation')
    plt.show()

# %% [markdown]
# ## DIVIDE DATA FOR ANALYSIS

# %%
#the data should be doublicated in order to run the analysis independantly
data1=data.copy()
data2=data.copy()

# Alternative you can divide the code into 2 files. DO NOT USE PCA data in KMEANS or the opposite

# %% [markdown]
# ## K-Means Clustering

# %% [markdown]
# ### A. Define the number of clusters (Elbow method)

# %%
#Fit data and calculate sum of squares(wss)
wss=[]
from sklearn.cluster import KMeans

for i in range (1,21):    
    kmeans=KMeans(n_clusters=i,init="k-means++")
    kmeans.fit(data1)
    wss.append(kmeans.inertia_)
# Out:
# C:\Users\32003\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] 系统找不到指定的文件。
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "C:\Users\32003\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#         "wmic CPU Get NumberOfCores /Format:csv".split(),
#         capture_output=True,
#         text=True,
#     )
#   File "C:\Users\32003\anaconda3\Lib\subprocess.py", line 554, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\32003\anaconda3\Lib\subprocess.py", line 1039, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#     ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                         pass_fds, cwd, env,
#                         ^^^^^^^^^^^^^^^^^^^
#     ...<5 lines>...
#                         gid, gids, uid, umask,
#                         ^^^^^^^^^^^^^^^^^^^^^^
#                         start_new_session, process_group)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\32003\anaconda3\Lib\subprocess.py", line 1554, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#                        ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#                              # no special security
#                              ^^^^^^^^^^^^^^^^^^^^^
#     ...<4 lines>...
#                              cwd,
#                              ^^^^
#                              startupinfo)
#                              ^^^^^^^^^^^^

# %%
#Visualisation of the k values in order to define the fittest
plt.figure(figsize=(10,8))
plt.plot(range(1,21),wss,marker="o", color="#dc00ff")
plt.xlabel("Number of K value")
plt.ylabel("WSS")
plt.title("Sum of squares vs number of clusters")
#plt.savefig("Elbow.png", dpi=300,transparent=True)
plt.show()

# %% [markdown]
# ### B.Clustering the data

# %%
#import library
from sklearn.cluster import KMeans

# %%
#pick number of clusters
kmeans = KMeans(n_clusters=6)

# %%
#fit the data
kmeans.fit(data1)
# Out:
# KMeans(n_clusters=6)

# %%
#find the cluster centers
kmeans.cluster_centers_
# Out:
# array([[ 2.99429508e-03, -1.46761889e-01, -1.22313640e-01,
#         -3.14385648e-02,  5.23274850e-01,  2.43509077e-01,
#          3.84131709e-01,  1.24192910e-01,  8.84197359e-02,
#          2.55654237e-01,  3.20308530e-01,  3.20308530e-01,
#          8.20670226e-02, -8.21424981e-02,  2.02821953e-01,
#          7.69462817e-03, -3.14863863e-02, -1.67092291e-01,
#         -1.03791371e-01, -2.84972683e-01, -1.51113975e-01,
#          1.37160698e-02,  1.67595875e-01, -4.95523332e-01,
#         -1.80884697e-03, -1.04109754e-01, -2.03974910e-01,
#         -1.00000000e+00,  4.96785073e-01,  1.00000000e+00,
#         -4.62135901e-02],
#        [ 7.47075592e-03, -1.44537350e-01, -1.20301716e-01,
#         -3.10832298e-02,  5.33886439e-01,  2.47297380e-01,
#          3.84073386e-01,  1.23818625e-01,  7.77235648e-02,
#          2.28046622e-01,  1.30391158e-01,  1.30391158e-01,
#          8.24070809e-02, -8.21560507e-02,  2.03215975e-01,
#          8.45481700e-03, -3.00937435e-02, -1.65010323e-01,
#         -1.02301618e-01, -2.83909580e-01, -1.50354096e-01,
#          1.53750565e-02,  1.67395739e-01, -4.95417121e-01,
#         -4.49634393e-04, -1.02572649e-01, -2.02322979e-01,
#         -1.00000000e+00,  4.98363315e-01,  1.00000000e+00,
#         -4.66611412e-02],
#        [-1.06700811e-02, -1.40743951e-01, -1.26363308e-01,
#         -3.17861011e-02,  5.16339869e-01,  2.38262911e-01,
#          3.82860419e-01,  1.02577069e-01,  8.39185453e-02,
#          2.13400085e-01, -3.61462980e-02, -3.61462980e-02,
#          8.50164819e-02, -8.17090330e-02,  1.99304810e-01,
#          8.42473393e-03, -3.33143222e-02, -1.63242042e-01,
#         -1.06264211e-01, -2.84741912e-01, -1.56538563e-01,
#          1.49601073e-02,  1.66610507e-01, -4.95407937e-01,
#          4.44799936e-04, -1.15952691e-01, -2.02735490e-01,
#         -9.95305164e-01,  4.54225352e-01, -1.00000000e+00,
#         -4.38597194e-02],
#        [-1.35647817e-02, -1.47039370e-01, -1.17489400e-01,
#         -2.97683322e-02,  5.38484077e-01,  2.36035925e-01,
#          3.83753477e-01,  1.17910760e-01,  8.33445347e-02,
#          2.20849313e-01,  3.91494361e-02,  3.91494361e-02,
#          8.15295694e-02, -8.17819551e-02,  2.05523709e-01,
#          7.16425070e-03, -3.20863983e-02, -1.65850019e-01,
#         -1.05195470e-01, -2.84040768e-01, -1.48824298e-01,
#          1.39780363e-02,  1.70436416e-01, -4.95910025e-01,
#         -5.67946836e-04, -1.02230339e-01, -2.02303472e-01,
#          1.00000000e+00,  5.00000000e-01,  9.96062992e-01,
#         -4.58791608e-02],
#        [-1.42421392e-02, -1.45911828e-01, -1.23728535e-01,
#         -3.15656144e-02,  5.45134074e-01,  2.44956622e-01,
#          3.83920693e-01,  1.21419888e-01,  6.81300281e-02,
#          1.89082412e-01, -1.25926792e-01, -1.25926792e-01,
#          8.06791520e-02, -8.29734167e-02,  2.02536940e-01,
#          6.63220442e-03, -3.29555532e-02, -1.66720025e-01,
#         -1.05516019e-01, -2.85105492e-01, -1.52537321e-01,
#          1.33986300e-02,  1.66891633e-01, -4.95669954e-01,
#         -3.32703074e-03, -1.08334812e-01, -2.04824846e-01,
#         -1.00000000e+00,  4.92578656e-01,  1.00000000e+00,
#         -4.75223810e-02],
#        [-2.84865320e-01, -1.81422697e-01, -1.50883883e-01,
#         -3.34968097e-02,  5.31068583e-01,  2.46069637e-01,
#          3.83832351e-01,  1.19411789e-01,  7.86110287e-02,
#          2.30385045e-01,  1.48624719e-01,  1.48624719e-01,
#          4.66187287e-02, -8.78809148e-02,  2.02170404e-01,
#         -1.84289641e-02, -7.19002110e-02, -2.04978339e-01,
#         -1.47747051e-01, -3.07849100e-01, -1.77226717e-01,
#         -1.85592484e-02,  1.54534853e-01, -5.02406584e-01,
#         -3.81635344e-02, -1.43261467e-01, -2.23413059e-01,
#         -1.00000000e+00,  4.97955247e-01,  1.00000000e+00,
#         -4.74665728e-02]])

# %%
#identify cluster labels
kmeans.labels_
# Out:
# array([1, 5, 1, ..., 1, 1, 5], dtype=int32)

# %%
#identify length of cluster labels
len(kmeans.labels_)
# Out:
# 166993

# %%
#Add cluster column in dataset
data1['CLUSTERS'] = kmeans.fit_predict(data1)

# %%
data1.head()
# Out:
#    Laplus transport_None  Laplus green15  Laplus 15mins  Laplus employe  \
# 0               0.272727       -0.117538      -0.123077       -0.031196
# 1              -0.127273       -0.165538      -0.123077       -0.031493
# 2              -0.018182       -0.147077      -0.123077       -0.031350
# 3              -0.018182       -0.147077      -0.123077       -0.031350
# 4              -0.018182       -0.147077      -0.123077       -0.031350
#
#    Laplus gps_join_osm_id_count  Laplus landmark_osm_id_count  \
# 0                      0.534759                          0.25
# 1                      0.534759                          0.25
# 2                      0.534759                          0.25
# 3                      0.534759                          0.25
# 4                      0.534759                          0.25
#
#    Laplus integration_intergation_T1024 Integration R800 metric_mean  \
# 0                                           0.384071
# 1                                           0.384071
# 2                                           0.384071
# 3                                           0.384071
# 4                                           0.384071
#
#    Laplus choice_15m_Metric Choice R800 metric_mean  \
# 0                                          0.123321
# 1                                          0.123321
# 2                                          0.123321
# 3                                          0.123321
# 4                                          0.123321
#
#    Laplus BuildingHeight_(mean)  Laplus BuildingVolumn  ...  Laplus Hindu  \
# 0                      0.078774               0.228839  ...      0.175835
# 1                      0.078774               0.228839  ...      0.158756
# 2                      0.078774               0.228839  ...      0.166412
# 3                      0.078774               0.228839  ...      0.166412
# 4                      0.078774               0.228839  ...      0.166412
#
#    Laplus Muslim  Laplus Acommodation_owned  \
# 0      -0.490617                   0.049326
# 1      -0.500267                  -0.044796
# 2      -0.495941                  -0.002603
# 3      -0.495941                  -0.002603
# 4      -0.495941                  -0.002603
#
#    Laplus Acommodation_Private rented  Laplus Acommodation_social rented  \
# 0                           -0.095265                          -0.198957
# 1                           -0.114106                          -0.207157
# 2                           -0.105660                          -0.203481
# 3                           -0.105660                          -0.203481
# 4                           -0.105660                          -0.203481
#
#    Laplus Educational_facilities_name_count  \
# 0                                      -1.0
# 1                                      -1.0
# 2                                      -1.0
# 3                                      -1.0
# 4                                      -1.0
#
#    Laplus Healthcare_facilities_name_count  Laplus supermarket_name_count  \
# 0                                      0.5                            1.0
# 1                                      0.5                            1.0
# 2                                      0.5                            1.0
# 3                                      0.5                            1.0
# 4                                      0.5                            1.0
#
#    Laplus UGS_Green space per capita_None  CLUSTERS
# 0                               -0.040909         0
# 1                               -0.051158         5
# 2                               -0.046564         0
# 3                               -0.046564         0
# 4                               -0.046564         0
#
# [5 rows x 32 columns]

# %%
#Count how many belong to each cluster
data1['CLUSTERS'].value_counts()
# Out:
# CLUSTERS
# 0    93418
# 3    30284
# 5    22623
# 1    18113
# 4     1538
# 2     1017
# Name: count, dtype: int64

# %% [markdown]
# ### C.Visualise your Kmeans result

# %%
'''
#Scatterplot of clustered data
sns.scatterplot(x=data1['vnl_NightLightmean'], y=data1['BAME%_re'], hue= kmeans.labels_, palette='rainbow')
plt.title('K-means Clustering')
plt.legend(loc=0,bbox_to_anchor=(1.2,0.5),title="Clusters")
plt.show()
'''

# Set the overall chart background to black (the font and axes will automatically turn white to match).
plt.style.use('dark_background')

# To draw a scatter plot, add `edgecolor='none'` to remove the white borders around the points.
sns.scatterplot(
    x=data1['no-native English speaker %'], 
    y=data1['activity limited%'], 
    hue=kmeans.labels_, 
    palette='rainbow',
    edgecolor='none' ,
    s=10
)

plt.title('K-means Clustering')
plt.legend(loc='center left', bbox_to_anchor=(1.05, 0.5), title="Clusters")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'no-native English speaker %'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 14
#      10 plt.style.use('dark_background')
#      12 # To draw a scatter plot, add `edgecolor='none'` to remove the white borders around the points.
#      13 sns.scatterplot(
# ---> 14     x=data1['no-native English speaker %'],
#      15     y=data1['activity limited%'],
#      16     hue=kmeans.labels_,
#      17     palette='rainbow',
#      18     edgecolor='none' ,
#      19     s=10
#      20 )
#      22 plt.title('K-means Clustering')
#      23 plt.legend(loc='center left', bbox_to_anchor=(1.05, 0.5), title="Clusters")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'no-native English speaker %'

# %% [markdown]
# #### Bring back data location to map in QGIS

# %%
final_df = pd.concat([datalocation, data1], axis=1)
final_df.head()

# %%
final_df[final_df['CLUSTERS'] == 0]

# %% [markdown]
# ## Principal Component Analysis

# %% [markdown]
# ### A. Preprocessing

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaler.fit(data2)

# %%
scaled_data = scaler.transform(data2)

# %% [markdown]
# ### B. Running PCA

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=4)

# %%
pca.fit(scaled_data)

# %%
x_pca = pca.transform(scaled_data)

# %%
scaled_data.shape #14 dimensions

# %%
x_pca.shape #3 dimensions (to interpret it as a 3D; PC1, PC2, PC3)

# %% [markdown]
# ### C.Interpretation of results

# %%
pca.components_

# %%
df_comp = pd.DataFrame(pca.components_,columns=data2.columns)

# %%
cmap = sns.diverging_palette(180, 295, s=100, l=50,
                                  n=10, center= "dark", as_cmap = True)

#Documentation: https://seaborn.pydata.org/generated/seaborn.diverging_palette.html

# %%
plt.figure(figsize=(40,12))
sns.heatmap(df_comp,cmap= cmap, annot=True,fmt = ".1f")

# %%
df_comp.head()

# %%
df=pd.DataFrame(x_pca, columns = ['0','1','2',"3"])

# %%
df.head()

# %%
datalocation.head()

# %%
plt.figure(figsize=(16,12))

# Set figure background to black
fig = plt.gcf()
fig.patch.set_facecolor('black')

# Get current axes and set its background to black
ax = plt.gca()
ax.set_facecolor('black')

# Set tick parameters color to white
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

# 1. Find the maximum boundary of absolute values
limit = np.max(np.abs(corr.values))

# Define custom colormap with specified colors and black at center
custom_colors = ['#1900d2', '#00f1ff', 'black', '#de00ff', '#7e21ff']
cmap = LinearSegmentedColormap.from_list("my_custom_cmap", custom_colors)

# 2. Plotting
sns.heatmap(df_comp,
            cmap= cmap,
            annot=True,
            fmt = ".1f",
            vmin=-limit,
            vmax=limit,
            center=0,
            annot_kws={"color": "white"}) # Set annotation text color to white

# Set title and axis labels color to white
plt.title('Heatmap of PCA Components', color='white')
plt.xlabel('Features', color='white')
plt.ylabel('Principal Components', color='white')

# Adjust colorbar label and tick label color
cbar = ax.collections[0].colorbar
cbar.ax.yaxis.set_tick_params(color='white')
cbar.ax.yaxis.label.set_color('white') # Set colorbar label color
plt.setp(cbar.ax.get_yticklabels(), color='white') # Set colorbar tick labels color to white

plt.show()

# %%
df_prefinal=pd.concat([df,datalocation],axis=1)

# %%
df_prefinal.head()

# %%
df_final=pd.concat([df_prefinal, data1],axis=1)

# %%
df_final.head()

# %%
df_final.to_csv('Laplacian Result 4PC 6Cl.csv', encoding='utf-8', index=False)
#df_final.to_csv('Phy Result 4PC 6Cl.csv', encoding='utf-8', index=False)
